# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import re

# %%
datapath = '../UniversityCases/'

# %% [markdown]
# ### Import and Clean Data

# %%
fnames = sorted(glob.glob(datapath+'*.csv'))
frames = []
for f in fnames:
    m = re.search(r'[^0-9]*([0-9][0-9_]+)[^0-9]*', f)
    df = pd.read_csv(f)
    df['Date'] = pd.to_datetime(m.group(1), format='%m_%d_%y')
    df.drop(['Unnamed: 0'], axis = 1, inplace=True)
    df['Cases'] = df['Cases'].apply(lambda x: x.replace(',', '')).astype('int')
    frames.append(df)
frames[0]
# Out:
#                                   School  Cases  County_Active_Cases  \
# 0                 Alabama A&M University      8               6574.0
# 1                Athens State University      2               1697.0
# 2                     Auburn University*   1074               3480.0
# 3        Auburn University at Montgomery      2               7800.0
# 4          Jacksonville State University    219               2571.0
# ...                                  ...    ...                  ...
# 1020   University of Wisconsin-Milwaukee     58              24442.0
# 1021    University of Wisconsin-Parkside      1               3001.0
# 1022  University of Wisconsin-Whitewater     18                 56.0
# 1023             Eastern Wyoming College      1                 66.0
# 1024               University of Wyoming     50               2707.0
#
#       County_Total_Cases          City      County      State       Date
# 0                 6631.0    Huntsville     Madison    Alabama 2020-09-08
# 1                 1715.0        Athens   Limestone    Alabama 2020-09-08
# 2                 3529.0        Auburn         Lee    Alabama 2020-09-08
# 3                 7963.0    Montgomery  Montgomery    Alabama 2020-09-08
# 4                 2602.0  Jacksonville     Calhoun    Alabama 2020-09-08
# ...                  ...           ...         ...        ...        ...
# 1020             24944.0     Milwaukee   Milwaukee  Wisconsin 2020-09-08
# 1021              3065.0        Somers     Kenosha  Wisconsin 2020-09-08
# 1022                56.0    Whitewater    Walworth  Wisconsin 2020-09-08
# 1023                67.0    Torrington      Goshen    Wyoming 2020-09-08
# 1024              2840.0       Laramie      Albany    Wyoming 2020-09-08
#
# [1025 rows x 8 columns]

# %%
df = pd.concat(frames)
df.index = pd.MultiIndex.from_frame(df[['School', 'Date']])
df.drop(['School', 'Date'], axis = 1, inplace = True)

# %%
df
# Out:
#                                               Cases  County_Active_Cases  \
# School                            Date
# Alabama A&M University            2020-09-08      8               6574.0
# Athens State University           2020-09-08      2               1697.0
# Auburn University*                2020-09-08   1074               3480.0
# Auburn University at Montgomery   2020-09-08      2               7800.0
# Jacksonville State University     2020-09-08    219               2571.0
# ...                                             ...                  ...
# Wisconsin Lutheran College        2020-11-06     34                  NaN
# Casper College                    2020-11-06    185                  NaN
# Eastern Wyoming College           2020-11-06      6                  NaN
# University of Wyoming             2020-11-06   1012                  NaN
# Western Wyoming Community College 2020-11-06     10                  NaN
#
#                                               County_Total_Cases  \
# School                            Date
# Alabama A&M University            2020-09-08              6631.0
# Athens State University           2020-09-08              1715.0
# Auburn University*                2020-09-08              3529.0
# Auburn University at Montgomery   2020-09-08              7963.0
# Jacksonville State University     2020-09-08              2602.0
# ...                                                          ...
# Wisconsin Lutheran College        2020-11-06                 NaN
# Casper College                    2020-11-06                 NaN
# Eastern Wyoming College           2020-11-06                 NaN
# University of Wyoming             2020-11-06                 NaN
# Western Wyoming Community College 2020-11-06                 NaN
#
#                                                       City      County  \
# School                            Date
# Alabama A&M University            2020-09-08    Huntsville     Madison
# Athens State University           2020-09-08        Athens   Limestone
# Auburn University*                2020-09-08        Auburn         Lee
# Auburn University at Montgomery   2020-09-08    Montgomery  Montgomery
# Jacksonville State University     2020-09-08  Jacksonville     Calhoun
# ...                                                    ...         ...
# Wisconsin Lutheran College        2020-11-06     Milwaukee         NaN
# Casper College                    2020-11-06        Casper         NaN
# Eastern Wyoming College           2020-11-06    Torrington         NaN
# University of Wyoming             2020-11-06       Laramie         NaN
# Western Wyoming Community College 2020-11-06  Rock Springs         NaN
#
#                                                   State
# School                            Date
# Alabama A&M University            2020-09-08    Alabama
# Athens State University           2020-09-08    Alabama
# Auburn University*                2020-09-08    Alabama
# Auburn University at Montgomery   2020-09-08    Alabama
# Jacksonville State University     2020-09-08    Alabama
# ...                                                 ...
# Wisconsin Lutheran College        2020-11-06  Wisconsin
# Casper College                    2020-11-06    Wyoming
# Eastern Wyoming College           2020-11-06    Wyoming
# University of Wyoming             2020-11-06    Wyoming
# Western Wyoming Community College 2020-11-06    Wyoming
#
# [72721 rows x 6 columns]

# %%
df.loc[(['Harvard University', 'Northeastern University', 'Boston University'],)]['Cases'].unstack().T.plot()

# %%
df.loc[(['Harvard University', 'Wellesley College','Boston University'],)]['County_Active_Cases'].unstack().T.plot()
